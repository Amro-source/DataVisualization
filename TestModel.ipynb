# %% [markdown]
# <a href="https://colab.research.google.com/github/Amro-source/DataVisualization/blob/main/TestModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This code module loads a custom model and loads an image , the model will figure out which object it has
#
# #from keras.models import load_model
# #import cv2
# #import numpy as np
#
# #model = load_model('model.h5')
#
# #model.compile(loss='binary_crossentropy',
#  #             optimizer='rmsprop',
#   #            metrics=['accuracy'])
#
# #img = cv2.imread('test.jpg')
# #img = cv2.resize(img,(320,240))
# #img = np.reshape(img,[1,320,240,3])
#
# #classes = model.predict_classes(img)
#
# #print classes

# %%
labels=['buffalo','elephant','rhino','zebra']
print(labels)
# Out:
# ['buffalo', 'elephant', 'rhino', 'zebra']

# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
# Out:
# 2.2.0

# %%
new_model = tf.keras.models.load_model('sample_data/my_model.h5')

# Check its architecture
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 100, 100, 64)      1792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 32)        18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1152)              4608
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                73792
# ...

# %%
import cv2
import numpy as np
img = cv2.imread('sample_data/Starry.jpeg')
img = cv2.resize(img,(100,100))
print(img.shape)
#print(img.dim)
print(img.size)
from matplotlib import pyplot as plt
plt.imshow(img)
plt.show()
img = np.reshape(img,[1,100,100,3])

#classes = new_model.predict_classes(img)

#print(classes)


#y_pred = model.predict(x_test)
# Out:
# (100, 100, 3)
# 30000

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("sample_data/cat.jpg")
plt.imshow(image)
plt.show()


import cv2
image = cv2.imread("sample_data/cat.jpg")
plt.axis("off")
plt.imshow(image)
plt.show()

plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img=image
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (Text(0.5, 1.0, 'Sobel Y'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
from scipy import misc
from matplotlib import pyplot as plt
import numpy as np
#get face image of panda from misc package
panda = misc.face()
#plot or show image of face
plt.imshow( panda )
plt.show()
